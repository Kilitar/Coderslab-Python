# %% [markdown]
# # Standard library
#
# ## Arithmetic operators

# %%
result_1 = 2 + 2 * 2
result_2 = (2 + 2) * 2
print(f"2 + 2 * 2 = {result_1}")
print(f"(2 + 2) * 2 = {result_2}")

# %% [markdown]
# result = 4 ** 0.5  # square root of 4
# print(result)

# %% [markdown]
# ## Boolean operators

# %%
print(100 == 100.0)
print(100 == 1e2)
print(100.0 == 1e2)

# %%
print(0.1 + 0.2 == 0.3)
print(round(0.1 + 0.2, 1) == 0.3)

# %%
result = 70 < 50
print(result)

# %% [markdown]
# ## Comparing strings

# %%
result_1 = "Alice" == "Alice"
result_2 = "Alice" == "alice"result_3 = "2" < "10"

print(result_1)
print(result_2)
print(result_3)

# %% [markdown]
# ### Combining logical values

# %%
is_ready = True
is_running = False

result_1 = is_ready and is_running
result_2 = is_ready or is_running
result_3 = is_ready ^ is_running
result_4 = not is_ready
result_5 = (is_ready == True) and (is_running == False)  # parentheses are optional; added for readability

print(result_1)
print(result_2)
print(result_3)
print(result_4)
print(result_5)

# %% [markdown]
# # Assignment operator

# %%
number = 42
text = "Lorem Ipsum"

# %%
i = 0
i = i + 1
i

# %%
i = 0
i = i - 1
i

# %%
i = 10

i += 1  # equivalent i = i + 1
print(i)

i -= 2  # equivalent i = i - 2
print(i)

i *= 10  # equivalent i = i * 10
print(i)

i **= 2  # equivalent i = i ** 2
print(i)

i /= 10  # equivalent i = i / 10
print(i)

i //= 7  # equivalent i = i // 7
print(i)

# %% [markdown]
# ## Type conversion

# %%
result = 42 + "EUR" # Note that there is going to be an error here!

# %%
text = str(2)  # '2'

# %%
value = int("42")  # 42

# %%
value = float(128)  # 128.0

# %%
letters = list("Alice has a cat")  # ['A', 'l', 'i', 'c', 'e', ' ', 'h', 'a', 's', ' ', 'a', ' ', 'c', 'a', 't']

# %%
text = str([42, "text"])  # "[42, 'text']"

# %%
is_checked = bool("checked")  # True
is_not_checked = bool("")  # False

# %%
value = int("blah") # Note that there is going to be an error here!

# %% [markdown]
# ## Useful Python built-in functions

# %%
result = abs(-42)  # 42

# %%
result = eval("2 + 2 * 2")  # 6

# %%
result = len([1, 2, 3])  # 3

# %%
result = max([1, 2, 3])  # 3

# %%
result = min([1, 2, 3])  # 1

# %%
result = pow(2, 10)  # equivalent to: result = 2 ** 10

# %%
result = sorted([2, 3, 1])  # [1, 2, 3]

# %%
result = sum([1, 2, 3])  # 6

# %%
result = type(42)  # int

# %%
result = round(3.14159, 2)  # 3.14
